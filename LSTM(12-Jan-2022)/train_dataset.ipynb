# %%
from datetime import date
import pandas as pd
import numpy as np
from nsepy import get_history

# %%
data=get_history('TATAMOTORS',date(2010,1,1),date(2017,12,31))
print(data)
# Out:
#                 Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2010-01-04  TATAMOTORS     EQ      791.55  789.90  829.00  789.30  827.05
# 2010-01-05  TATAMOTORS     EQ      826.45  820.00  844.70  774.45  813.55
# 2010-01-06  TATAMOTORS     EQ      812.05  819.70  823.40  805.10  813.90
# 2010-01-07  TATAMOTORS     EQ      813.30  814.50  818.30  780.00  783.00
# 2010-01-08  TATAMOTORS     EQ      785.50  790.00  804.80  785.05  789.25
# ...                ...    ...         ...     ...     ...     ...     ...
# 2017-12-22  TATAMOTORS     EQ      420.80  422.05  426.40  420.90  421.40
# 2017-12-26  TATAMOTORS     EQ      422.00  422.00  425.15  421.15  423.00
# 2017-12-27  TATAMOTORS     EQ      424.20  423.50  428.45  420.30  421.10
# 2017-12-28  TATAMOTORS     EQ      422.45  423.50  423.70  416.00  417.50
# 2017-12-29  TATAMOTORS     EQ      418.60  418.00  433.45  417.15  431.20
#
#              Close    VWAP   Volume      Turnover   Trades  \
# Date
# ...

# %%
data.to_csv('TATA_train.csv')

# %%
data.head()
# Out:
#                 Symbol Series  Prev Close   Open   High     Low    Last  \
# Date
# 2010-01-04  TATAMOTORS     EQ      791.55  789.9  829.0  789.30  827.05
# 2010-01-05  TATAMOTORS     EQ      826.45  820.0  844.7  774.45  813.55
# 2010-01-06  TATAMOTORS     EQ      812.05  819.7  823.4  805.10  813.90
# 2010-01-07  TATAMOTORS     EQ      813.30  814.5  818.3  780.00  783.00
# 2010-01-08  TATAMOTORS     EQ      785.50  790.0  804.8  785.05  789.25
#
#              Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2010-01-04  826.45  815.65  5522060  4.504044e+14     NaN             1371877
# 2010-01-05  812.05  823.43  4683627  3.856629e+14     NaN             1205901
# 2010-01-06  813.30  814.75  2966347  2.416823e+14     NaN              572579
# 2010-01-07  785.50  789.80  4496180  3.551081e+14     NaN             1103551
# 2010-01-08  789.80  794.78  3264144  2.594286e+14     NaN              614256
#
#             %Deliverble
# Date
# ...

# %%
data=pd.read_csv('TATA_train.csv')

# %%
data2=get_history('TATAMOTORS',date(2018,1,1),date(2022,12,31))
print(data2)
# Out:
#                 Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2018-01-01  TATAMOTORS     EQ      431.85  430.95  436.40  422.25  424.50
# 2018-01-02  TATAMOTORS     EQ      424.45  428.85  440.85  422.00  438.20
# 2018-01-03  TATAMOTORS     EQ      439.30  440.40  441.40  431.95  433.45
# 2018-01-04  TATAMOTORS     EQ      433.90  430.00  433.30  425.75  430.00
# 2018-01-05  TATAMOTORS     EQ      429.95  431.25  436.35  429.80  430.35
# ...                ...    ...         ...     ...     ...     ...     ...
# 2022-12-26  TATAMOTORS     EQ      378.35  380.25  390.70  375.20  385.50
# 2022-12-27  TATAMOTORS     EQ      384.80  390.00  397.45  388.50  395.10
# 2022-12-28  TATAMOTORS     EQ      394.15  394.00  395.90  390.40  390.75
# 2022-12-29  TATAMOTORS     EQ      391.30  389.00  390.00  383.05  386.50
# 2022-12-30  TATAMOTORS     EQ      385.90  391.00  392.20  387.00  388.00
#
#              Close    VWAP    Volume      Turnover  Trades  \
# Date
# ...

# %%
data2.to_csv('TATA_test.csv')

# %%
data3=get_history('ADANIENT',date(2010,1,1),date(2017,12,31))
print(data3)
# Out:
#               Symbol Series  Prev Close    Open    High     Low    Last  \
# Date
# 2010-01-04  ADANIENT     EQ      436.00  437.20  454.00  433.00  453.45
# 2010-01-05  ADANIENT     EQ      451.60  453.00  463.95  453.00  462.00
# 2010-01-06  ADANIENT     EQ      462.05  463.00  517.00  460.00  513.00
# 2010-01-07  ADANIENT     EQ      507.65  519.40  519.40  483.00  488.15
# 2010-01-08  ADANIENT     EQ      486.70  489.80  508.00  482.20  498.80
# ...              ...    ...         ...     ...     ...     ...     ...
# 2017-12-22  ADANIENT     EQ      162.60  162.95  165.95  161.10  162.20
# 2017-12-26  ADANIENT     EQ      162.90  163.00  165.20  160.95  162.80
# 2017-12-27  ADANIENT     EQ      163.20  163.00  169.35  162.40  165.25
# 2017-12-28  ADANIENT     EQ      165.95  166.00  167.20  163.50  164.50
# 2017-12-29  ADANIENT     EQ      165.25  165.00  168.25  163.90  165.50
#
#              Close    VWAP   Volume      Turnover   Trades  \
# Date
# ...

# %%
data3.to_csv('ADANI_test.csv')

# %%
data4=get_history('ADANIENT',date(2018,1,1),date(2022,12,31))
print(data4)
# Out:
#               Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2018-01-01  ADANIENT     EQ      166.35   165.80   169.85   165.00   165.60
# 2018-01-02  ADANIENT     EQ      166.05   166.10   167.40   162.15   163.40
# 2018-01-03  ADANIENT     EQ      163.90   163.90   180.25   163.90   176.50
# 2018-01-04  ADANIENT     EQ      176.20   176.00   185.20   174.15   183.30
# 2018-01-05  ADANIENT     EQ      183.30   184.80   194.30   182.40   192.85
# ...              ...    ...         ...      ...      ...      ...      ...
# 2022-12-26  ADANIENT     EQ     3642.20  3653.00  3744.90  3620.00  3709.00
# 2022-12-27  ADANIENT     EQ     3716.75  3732.45  3797.90  3695.05  3767.15
# 2022-12-28  ADANIENT     EQ     3769.65  3756.05  3825.00  3745.00  3797.95
# 2022-12-29  ADANIENT     EQ     3797.70  3790.00  3825.00  3748.10  3815.35
# 2022-12-30  ADANIENT     EQ     3810.60  3829.70  3898.00  3822.05  3850.00
#
# ...

# %%
data4.to_csv('ADANI_train.csv')

# %%
data5=get_history('SBIN',date(2010,1,1),date(2017,12,31))
print(data5)
# Out:
#            Symbol Series  Prev Close    Open     High      Low     Last  \
# Date
# 2010-05-12   SBIN     EQ     2287.85  2290.0  2339.00  2282.00  2321.60
# 2010-05-13   SBIN     EQ     2324.20  2332.0  2349.00  2306.20  2310.60
# 2010-05-14   SBIN     EQ     2317.75  2315.0  2333.90  2211.60  2213.80
# 2010-05-17   SBIN     EQ     2224.25  2210.0  2272.00  2141.35  2250.00
# 2010-05-18   SBIN     EQ     2250.75  2247.9  2298.00  2231.35  2280.35
# ...           ...    ...         ...     ...      ...      ...      ...
# 2017-12-22   SBIN     EQ      316.75   317.1   323.85   316.50   319.10
# 2017-12-26   SBIN     EQ      319.85   318.6   319.95   316.30   317.00
# 2017-12-27   SBIN     EQ      317.15   316.5   320.30   313.05   313.45
# 2017-12-28   SBIN     EQ      314.85   315.3   316.50   307.65   308.30
# 2017-12-29   SBIN     EQ      308.40   310.0   312.00   309.05   310.00
#
#               Close     VWAP    Volume      Turnover  Trades  \
# Date
# ...

# %%
data5.to_csv('SBI_test.csv')

# %%
data6=get_history('SBIN',date(2018,1,1),date(2022,12,31))
print(data6)
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2018-01-01   SBIN     EQ      309.90  310.60  312.75  306.30  306.75  307.10
# 2018-01-02   SBIN     EQ      307.10  309.00  309.00  301.35  303.00  303.25
# 2018-01-03   SBIN     EQ      303.25  305.30  306.45  302.15  302.80  302.85
# 2018-01-04   SBIN     EQ      302.85  304.50  310.20  303.15  309.25  308.50
# 2018-01-05   SBIN     EQ      308.50  311.40  311.40  305.60  307.25  306.35
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2022-12-26   SBIN     EQ      574.00  574.00  601.70  570.70  597.10  597.10
# 2022-12-27   SBIN     EQ      597.10  600.40  603.10  593.30  602.00  601.90
# 2022-12-28   SBIN     EQ      601.90  600.90  607.00  598.55  601.00  601.05
# 2022-12-29   SBIN     EQ      601.05  600.00  618.00  597.15  614.05  611.80
# 2022-12-30   SBIN     EQ      611.80  615.25  620.55  611.35  614.25  613.70
#
# ...

# %%
data6.to_csv('SBI_test.csv')

# %%
data7=get_history('SBIN',date(2010,1,1),date(2017,12,31))
print(data7)
# Out:
#            Symbol Series  Prev Close    Open     High      Low     Last  \
# Date
# 2010-01-04   SBIN     EQ     2269.00  2275.0  2300.00  2275.00  2294.00
# 2010-01-05   SBIN     EQ     2291.20  2308.0  2310.00  2280.10  2294.00
# 2010-01-06   SBIN     EQ     2292.05  2297.0  2315.00  2285.00  2300.00
# 2010-01-07   SBIN     EQ     2305.80  2306.0  2310.00  2281.10  2292.00
# 2010-01-08   SBIN     EQ     2292.90  2294.0  2303.90  2280.10  2287.70
# ...           ...    ...         ...     ...      ...      ...      ...
# 2017-12-22   SBIN     EQ      316.75   317.1   323.85   316.50   319.10
# 2017-12-26   SBIN     EQ      319.85   318.6   319.95   316.30   317.00
# 2017-12-27   SBIN     EQ      317.15   316.5   320.30   313.05   313.45
# 2017-12-28   SBIN     EQ      314.85   315.3   316.50   307.65   308.30
# 2017-12-29   SBIN     EQ      308.40   310.0   312.00   309.05   310.00
#
#               Close     VWAP    Volume      Turnover    Trades  \
# Date
# ...

# %%
data7.to_csv('SBI_train.csv')

# %%
data8=get_history('RELIANCE',date(2018,1,1),date(2022,12,31))
print(data8)
# Out:
#               Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2018-05-14  RELIANCE     EQ      989.25   991.95   991.95   976.70   984.95
# 2018-05-15  RELIANCE     EQ      986.60   983.05  1000.00   976.65   978.55
# 2018-05-16  RELIANCE     EQ      978.95   974.00   974.00   952.45   954.40
# 2018-05-17  RELIANCE     EQ      956.15   959.35   960.00   941.50   944.00
# 2018-05-18  RELIANCE     EQ      945.35   945.60   953.50   932.00   934.50
# ...              ...    ...         ...      ...      ...      ...      ...
# 2021-12-06  RELIANCE     EQ     2408.25  2416.00  2425.00  2357.15  2365.95
# 2021-12-07  RELIANCE     EQ     2362.60  2376.15  2404.00  2360.00  2382.00
# 2021-12-08  RELIANCE     EQ     2381.85  2424.10  2431.80  2406.30  2420.95
# 2021-12-09  RELIANCE     EQ     2418.10  2435.00  2474.90  2425.00  2453.00
# 2021-12-10  RELIANCE     EQ     2456.45  2440.25  2466.00  2430.35  2457.25
#
# ...

# %%
data8.to_csv('Rel_test.csv')

# %%
data10=get_history('RELIANCE',date(2010,1,1),date(2017,12,31))
print(data10)
# Out:
#               Symbol Series  Prev Close     Open    High      Low     Last  \
# Date
# 2010-01-04  RELIANCE     EQ     1090.55  1091.10  1091.1  1021.85  1077.30
# 2010-01-05  RELIANCE     EQ     1075.50  1149.90  1149.9  1065.40  1068.70
# 2010-01-06  RELIANCE     EQ     1070.70  1079.90  1094.5  1070.65  1087.00
# 2010-01-07  RELIANCE     EQ     1088.00  1088.00  1115.0  1078.00  1101.90
# 2010-01-08  RELIANCE     EQ     1106.05  1108.00  1113.8  1096.00  1103.90
# ...              ...    ...         ...      ...     ...      ...      ...
# 2017-12-22  RELIANCE     EQ      912.95   914.65   922.4   909.30   919.80
# 2017-12-26  RELIANCE     EQ      920.40   924.85   938.9   918.15   936.00
# 2017-12-27  RELIANCE     EQ      929.80   933.00   937.5   919.00   923.25
# 2017-12-28  RELIANCE     EQ      923.75   925.25   934.4   919.10   922.60
# 2017-12-29  RELIANCE     EQ      924.20   926.50   932.3   918.50   920.10
#
# ...

# %%
data10.to_csv('rel_train.csv')

# %%
data11=get_history('BAJFINANCE',date(2010,1,1),date(2017,12,31))
print(data11)
# Out:
#                 Symbol Series  Prev Close     Open    High      Low     Last  \
# Date
# 2010-01-04  BAJAUTOFIN     EQ      329.95   332.70   344.9   332.70   343.30
# 2010-01-05  BAJAUTOFIN     EQ      343.10   350.05   350.7   336.00   341.00
# 2010-01-06  BAJAUTOFIN     EQ      340.80   341.00   351.0   335.20   347.85
# 2010-01-07  BAJAUTOFIN     EQ      345.70   349.90   349.9   339.00   342.00
# 2010-01-08  BAJAUTOFIN     EQ      343.60   344.10   359.0   342.45   348.00
# ...                ...    ...         ...      ...     ...      ...      ...
# 2017-12-22  BAJFINANCE     EQ     1748.05  1756.00  1788.4  1750.00  1776.05
# 2017-12-26  BAJFINANCE     EQ     1782.45  1784.70  1795.0  1774.20  1788.00
# 2017-12-27  BAJFINANCE     EQ     1789.50  1797.20  1797.6  1762.00  1768.90
# 2017-12-28  BAJFINANCE     EQ     1770.95  1780.00  1782.0  1745.50  1749.00
# 2017-12-29  BAJFINANCE     EQ     1755.15  1749.25  1765.9  1748.15  1760.00
#
# ...

# %%
data11.to_csv('baj_train.csv')

# %%
data12=get_history('BAJFINANCE',date(2018,1,1),date(2022,12,31))
print(data12)
# Out:
#                 Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2018-01-01  BAJFINANCE     EQ     1756.70  1759.50  1760.00  1720.40  1733.85
# 2018-01-02  BAJFINANCE     EQ     1725.65  1739.70  1739.70  1710.00  1722.00
# 2018-01-03  BAJFINANCE     EQ     1724.65  1727.00  1738.35  1711.00  1714.55
# 2018-01-04  BAJFINANCE     EQ     1715.30  1725.00  1758.25  1714.00  1753.30
# 2018-01-05  BAJFINANCE     EQ     1754.00  1766.00  1821.00  1759.10  1818.00
# ...                ...    ...         ...      ...      ...      ...      ...
# 2022-12-26  BAJFINANCE     EQ     6374.60  6374.65  6469.90  6300.00  6422.00
# 2022-12-27  BAJFINANCE     EQ     6433.70  6466.00  6530.00  6430.00  6505.00
# 2022-12-28  BAJFINANCE     EQ     6504.70  6475.00  6570.00  6464.05  6469.00
# 2022-12-29  BAJFINANCE     EQ     6476.10  6440.00  6520.50  6402.40  6511.00
# 2022-12-30  BAJFINANCE     EQ     6510.90  6550.00  6719.90  6515.00  6577.00
#
# ...

# %%
data12.to_csv('baj_test.csv')
