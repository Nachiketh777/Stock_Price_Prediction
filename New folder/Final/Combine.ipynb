# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('tatatest.csv')
data.head()
# Out:
#          Date      Symbol    Open    High     Low   Close    Volume
# 0  2018-01-01  TATAMOTORS  430.95  436.40  422.25  424.45   6807536
# 1  2018-01-02  TATAMOTORS  428.85  440.85  422.00  439.30  15331261
# 2  2018-01-03  TATAMOTORS  440.40  441.40  431.95  433.90   9794953
# 3  2018-01-04  TATAMOTORS  430.00  433.30  425.75  429.95   8395377
# 4  2018-01-05  TATAMOTORS  431.25  436.35  429.80  431.60   7021611

# %%
tata_test=data["Close"].tolist()

# %%
print(type(tata_test))
# Out:
# <class 'list'>

# %%
data2=pd.read_csv('adanitest.csv')
data2.head()
# Out:
#          Date    Symbol   Open    High     Low   Close    Volume
# 0  2018-01-01  ADANIENT  165.8  169.85  165.00  166.05   4220395
# 1  2018-01-02  ADANIENT  166.1  167.40  162.15  163.90   2712044
# 2  2018-01-03  ADANIENT  163.9  180.25  163.90  176.20  21268697
# 3  2018-01-04  ADANIENT  176.0  185.20  174.15  183.30  12411875
# 4  2018-01-05  ADANIENT  184.8  194.30  182.40  193.15  11521764

# %%
data3=pd.read_csv('sbitest.csv')
data3.head()
# Out:
#          Date Symbol   Open    High     Low   Close    Volume
# 0  2018-01-01   SBIN  310.6  312.75  306.30  307.10  12182400
# 1  2018-01-02   SBIN  309.0  309.00  301.35  303.25  14797364
# 2  2018-01-03   SBIN  305.3  306.45  302.15  302.85  13857373
# 3  2018-01-04   SBIN  304.5  310.20  303.15  308.50  24517099
# 4  2018-01-05   SBIN  311.4  311.40  305.60  306.35  14580575

# %%
data4=pd.read_csv('bajtest.csv')
data4.head()
# Out:
#          Date      Symbol    Open     High     Low    Close  Volume
# 0  2018-01-01  BAJFINANCE  1759.5  1760.00  1720.4  1725.65  535319
# 1  2018-01-02  BAJFINANCE  1739.7  1739.70  1710.0  1724.65  576208
# 2  2018-01-03  BAJFINANCE  1727.0  1738.35  1711.0  1715.30  416136
# 3  2018-01-04  BAJFINANCE  1725.0  1758.25  1714.0  1754.00  730147
# 4  2018-01-05  BAJFINANCE  1766.0  1821.00  1759.1  1814.50  984327

# %%
data5=pd.read_csv('rel_test.csv')
data5.head()
# Out:
#          Date    Symbol Series  Prev Close    Open    High     Low   Last  \
# 0  2018-01-01  RELIANCE     EQ      921.05  922.70  922.70  907.50  909.5
# 1  2018-01-02  RELIANCE     EQ      909.75  913.00  919.55  906.40  911.5
# 2  2018-01-03  RELIANCE     EQ      911.15  925.00  926.00  913.05  915.5
# 3  2018-01-04  RELIANCE     EQ      914.80  918.15  921.80  915.70  920.5
# 4  2018-01-05  RELIANCE     EQ      920.30  921.80  926.90  920.25  923.0
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  909.75  913.43  4321686  3.947569e+14   61538             2615951
# 1  911.15  912.92  4342815  3.964649e+14   63346             1835805
# 2  914.80  920.10  6175312  5.681898e+14  101162             2679871
# 3  920.30  919.08  4118581  3.785310e+14   92195             2666331
# 4  923.25  923.12  3401905  3.140379e+14   59095             1641153
#
#    %Deliverble
# 0       0.6053
# 1       0.4227
# 2       0.4340
# 3       0.6474
# 4       0.4824

# %%
adani_test=data2["Close"].tolist()
print(type(adani_test))
# Out:
# <class 'list'>

# %%
sbi_test=data3["Close"].tolist()
print(type(sbi_test))
# Out:
# <class 'list'>

# %%
sbi_year=data3["Date"].tolist()
print(type(sbi_year))
# Out:
# <class 'list'>

# %%
baj_test=data4["Close"].tolist()
print(type(baj_test))
# Out:
# <class 'list'>

# %%
baj_year=data4["Date"].tolist()
print(type(baj_year))
# Out:
# <class 'list'>

# %%
rel_test=data5["Close"].tolist()
print(type(rel_test))
# Out:
# <class 'list'>

# %%
rel_year=data5["Date"].tolist()
print(type(rel_year))
# Out:
# <class 'list'>

# %%
print(data5)
# Out:
#             Date    Symbol Series  Prev Close     Open     High      Low  \
# 0     2018-01-01  RELIANCE     EQ      921.05   922.70   922.70   907.50
# 1     2018-01-02  RELIANCE     EQ      909.75   913.00   919.55   906.40
# 2     2018-01-03  RELIANCE     EQ      911.15   925.00   926.00   913.05
# 3     2018-01-04  RELIANCE     EQ      914.80   918.15   921.80   915.70
# 4     2018-01-05  RELIANCE     EQ      920.30   921.80   926.90   920.25
# ...          ...       ...    ...         ...      ...      ...      ...
# 1234  2022-12-26  RELIANCE     EQ     2502.20  2514.75  2542.00  2492.40
# 1235  2022-12-27  RELIANCE     EQ     2524.05  2530.00  2548.80  2515.25
# 1236  2022-12-28  RELIANCE     EQ     2544.70  2538.00  2549.80  2521.50
# 1237  2022-12-29  RELIANCE     EQ     2544.45  2527.00  2548.90  2525.50
# 1238  2022-12-30  RELIANCE     EQ     2543.30  2545.10  2577.00  2541.10
#
#          Last    Close     VWAP   Volume      Turnover  Trades  \
# ...

# %%
adani_year=data2["Date"].tolist()
print(type(adani_year))
# Out:
# <class 'list'>

# %%
print(adani_test)
# Out:
# [166.05, 163.9, 176.2, 183.3, 193.15, 196.45, 195.9, 198.8, 201.7, 199.95, 198.2, 194.6, 204.55, 195.25, 199.7, 198.9, 204.4, 205.5, 214.4, 213.35, 211.3, 213.2, 214.0, 197.2, 199.45, 195.3, 196.75, 204.5, 210.1, 217.25, 219.45, 214.75, 207.8, 202.9, 198.0, 197.4, 203.3, 204.35, 205.6, 207.05, 203.55, 199.15, 200.9, 186.2, 172.2, 168.95, 156.1, 162.25, 159.75, 163.75, 167.05, 160.5, 160.6, 160.95, 162.2, 159.45, 152.45, 163.75, 159.9, 156.4, 160.9, 162.4, 151.45, 147.85, 149.75, 147.15, 147.75, 144.55, 136.1, 139.4, 140.75, 139.5, 136.75, 141.65, 137.7, 139.75, 137.9, 137.55, 140.55, 141.8, 140.1, 129.4, 126.4, 126.6, 127.6, 131.45, 129.05, 126.65, 127.8, 124.0, 123.3, 123.1, 123.4, 118.6, 118.2, 122.25, 117.4, 119.15, 124.8, 129.65, 123.7, 123.4, 121.0, 119.55, 116.25, 115.4, 118.25, 125.4, 126.3, 128.25, 127.65, 129.15, 133.95, 132.45, 134.35, 129.9, 131.75, 129.85, 130.35, 127.0, 129.15, 115.1, 109.35, 113.15, 105.05, 106.25, 107.7, 105.9, 110.95, 111.65, 114.1, 124.1, 124.3, 131.
# ...

# %%
print(data2)
# Out:
#             Date    Symbol     Open     High      Low    Close    Volume
# 0     2018-01-01  ADANIENT   165.80   169.85   165.00   166.05   4220395
# 1     2018-01-02  ADANIENT   166.10   167.40   162.15   163.90   2712044
# 2     2018-01-03  ADANIENT   163.90   180.25   163.90   176.20  21268697
# 3     2018-01-04  ADANIENT   176.00   185.20   174.15   183.30  12411875
# 4     2018-01-05  ADANIENT   184.80   194.30   182.40   193.15  11521764
# ...          ...       ...      ...      ...      ...      ...       ...
# 1234  2022-12-26  ADANIENT  3653.00  3744.90  3620.00  3716.75   2162662
# 1235  2022-12-27  ADANIENT  3732.45  3797.90  3695.05  3769.65   1804911
# 1236  2022-12-28  ADANIENT  3756.05  3825.00  3745.00  3797.70   1377950
# 1237  2022-12-29  ADANIENT  3790.00  3825.00  3748.10  3810.60   1531692
# 1238  2022-12-30  ADANIENT  3829.70  3898.00  3822.05  3858.35   1528747
#
# [1239 rows x 7 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1239 entries, 0 to 1238
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1239 non-null   object
#  1   Symbol  1239 non-null   object
#  2   Open    1239 non-null   float64
#  3   High    1239 non-null   float64
#  4   Low     1239 non-null   float64
#  5   Close   1239 non-null   float64
#  6   Volume  1239 non-null   int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 67.9+ KB

# %%
tata_year=data["Date"].tolist()
print(type(tata_year))
# Out:
# <class 'list'>

# %%
print(tata_test)
# Out:
# [424.45, 439.3, 433.9, 429.95, 431.6, 433.55, 437.55, 433.3, 434.75, 437.1, 432.35, 421.9, 422.95, 418.95, 418.05, 421.9, 418.0, 403.6, 400.3, 399.25, 395.85, 399.5, 393.65, 383.75, 395.8, 375.45, 377.8, 374.85, 368.75, 371.8, 376.85, 375.8, 370.75, 368.75, 369.3, 364.45, 358.5, 360.2, 372.05, 372.55, 369.9, 370.75, 352.05, 346.5, 347.8, 345.15, 341.5, 352.6, 353.15, 354.05, 353.1, 339.75, 335.7, 338.8, 333.85, 338.2, 330.85, 332.35, 331.15, 326.85, 339.15, 343.1, 355.6, 362.2, 364.1, 358.3, 353.25, 355.8, 358.4, 357.05, 339.15, 336.45, 334.8, 334.25, 336.0, 334.05, 331.55, 328.6, 330.25, 336.9, 340.4, 336.05, 333.5, 334.4, 335.15, 332.15, 341.95, 333.6, 330.8, 323.6, 310.1, 310.25, 314.9, 304.6, 295.9, 307.7, 309.45, 288.65, 294.15, 296.3, 294.65, 288.9, 282.5, 287.2, 286.65, 284.95, 295.65, 305.4, 309.95, 309.75, 307.8, 308.4, 305.9, 302.95, 308.8, 305.05, 305.6, 307.0, 308.0, 289.4, 276.85, 271.05, 263.35, 269.3, 266.7, 269.45, 267.05, 261.55, 270.85, 273.5, 275.45, 267.8, 266.1, 
# ...

# %%
print(year)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6720\2369430430.py in <module>
# ----> 1 print(year)
#
# NameError: name 'year' is not defined

# %%
fig=plt.figure(figsize=(15,5))
ax=fig.add_subplot(121)
ax.plot(adani_test,color='blue')
ax.set_xticks(np.arange(0,len(tata_year)+1,249))
plt.plot(tata_year,tata_test,label='tata')
plt.plot(adani_year,adani_test,label='adani')
plt.plot(sbi_year,sbi_test,label='sbi')
plt.plot(baj_year,baj_test,label='bajaj')
plt.plot(rel_year,rel_test,label='rel')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
